# %% [markdown]
# File with functions for cleaning data for use in app.py. Cleans the raw recipes.csv data and exports as recipe_data.csv.
#
# Adds dietary label variable to recipe_data df. Also converts time strings to integer minutes, for prep_time, cook_time, and total_time, to make cleaned versions of those variables (cleaned_prep_time, etc.)

# %%
import pandas as pd
from collections import Counter
import re

# %%
recipe_data = pd.read_csv("data/recipes.csv")

# %%
column_name = "ingredients"

word_bank = []

measurements = ["cups", "cup", "tbsp", "tablespoons", "tablespoon", "tsp", "teaspoons", "teaspoon",
    "oz", "ounces", "ounce", "pounds", "pound", "lbs", "lb", "grams", "gram", "kg", "kilograms", "kilogram",
    "ml", "milliliters", "milliliter", "liters", "liter", "quarts", "quart", "pints", "pint", "gallons", "gallon"]

fractions = ['½', '¼', '¾', '⅓', '⅔', '⅛', '⅜', '⅝', '⅞']

verbs = ["chopped", "softened", "or to taste", "or as needed", "divided", "melted", "or more to taste", "juiced", 
         "peeled", "drained", "cored", "minced", "beaten", "sliced", "diced", "pitted", "and sliced", "thawed", 
         "cored and chopped", "quartered", "pitted and chopped", "thinly sliced", "mashed", "halved", "seeded", 
         "skinless", "cored and sliced", "pitted and sliced", "finely chopped", "peeled and diced", "peeled and sliced", 
         "pitted and diced", "seeded and diced", "and diced", "or more as needed", "halved and pitted", "lightly beaten", 
         "and chopped", "cut into cubes", "cut into pieces", "crushed", "at room temperature", "cut into chunks", "cored and diced", 
         "and cubed", "room temperature", "cut into -inch cubes", "seeded and chopped", "for garnish", "peeled and chopped", 
         "seeded and cubed", "hulled", "broken into chunks", "peeled and pitted", "and cut into chunks", "cubed", "zested", "shredded",
         "cored and thinly sliced", "peeled and cored", "roughly chopped", "drained with juice reserved", "crumbled", "seeded and minced",
         "toasted", "baked", "stemmed and quarted", "cut into wedges", "coarsely chopped", "peeled and seeds separated", "drained and rinsed", 
         "cored and sliced /-inch thick", "and sliced /-inch thick", "thawed but still cold follow package directions", "cored and sliced / inch thick",
         "heated"]

for index, row in recipe_data.iterrows():
    ingredients = str(row[column_name]).lower()  # Convert to lowercase

    # Remove parentheses by replacing them with empty strings
    ingredients = ingredients.replace("(", "").replace(")", "")
    
    # Remove digits by iterating through characters
    ingredients = ''.join([char if not char.isdigit() else '' for char in ingredients])
    
    for fraction in fractions:
        ingredients = ingredients.replace(fraction, "")

    for verb in verbs:
        ingredients = ingredients.replace(verb, '')
        
    # Split ingredients by commas
    ingredient_list = [ingredient.strip() for ingredient in ingredients.split(',') if ingredient.strip()]
    
    # Filter out measurements and empty strings
    filtered_ingredients = []
    for ingredient in ingredient_list:
        words = ingredient.split()
        filtered_words = [word for word in words if word not in measurements]
        if filtered_words:
            filtered_ingredients.append(" ".join(filtered_words))
   
    for ingredient in filtered_ingredients:
        word_bank.append(ingredient)

word_frequency = Counter(word_bank)

non_vegetarian = ['chicken', 'beef', 'lamb', 'thighs', 'duck', 'pork', 
                  'fish', 'lobster', 'salmon', 'cod', 'trout', 'tuna', 
                  'sardine', 'mackerel', 'catfish', 'halibut', 'tilapia', 
                  'mahi-mahi', 'veal', 'goose', 'turkey', 'quail', 
                  'scallops', 'calamari', 'crab', 'fish sauce', 'roughy']
non_vegan = non_vegetarian + ['egg', 'milk', 'cheese', 'yogurt', 'butter', 'honey']
# Out:
# Counter({'white sugar': 587, 'and': 359, 'butter': 320, 'all-purpose flour': 315, 'salt': 296, 'ground cinnamon': 257, 'vanilla extract': 202, 'water': 179, 'baking powder': 145, 'baking soda': 134, 'milk': 134, 'brown sugar': 128, 'eggs': 126, 'lemon juice': 104, 'ground nutmeg': 86, 'vegetable oil': 83, 'olive oil': 78, 'egg': 67, 'walnuts': 67, 'cornstarch': 65, 'unsalted butter': 59, 'packed brown sugar': 57, 'honey': 56, 'large eggs': 55, 'pecans': 45, 'cloves garlic': 42, 'salt and ground black pepper to taste': 41, 'ground black pepper': 39, 'fresh cilantro': 38, 'lemon': 36, 'onion': 35, 'pinch salt': 34, 'ground cloves': 33, 'flaked coconut': 33, 'margarine': 32, "confectioners' sugar": 31, 'thinly': 31, 'sugar': 29, 'apples -': 29, 'orange juice': 28, 'dates': 28, 'ground allspice': 27, 'raisins': 27, 'large egg': 27, 'ice cubes': 27, 'bananas': 27, 'apples': 26, 'rolled oats': 26, 'ground ginger': 26, 'fresh lemon juice': 26, 'fresh strawberries': 26, 'banana': 26, 'balsamic vinegar': 26, 'lime juice': 26, 'can pineapple': 25, 'lime': 25, 'package cream cheese': 24, 'fresh figs': 24, 'watermelon': 24, 'finely': 23, 'heavy cream': 22, 'almond extract': 22, 'strawberries': 22, 'clove garlic': 22, 'dried cranberries': 21, 'boiling water': 21, 'extra-virgin olive oil': 21, 'buttermilk': 20, 'can sweetened condensed milk': 19, 'lemon zest': 19, 'ground cumin': 19, 'avocado -': 19, 'soy sauce': 19, 'sour cream': 19, 'salt to taste': 19, 'dried apricots': 19, 'ice': 18, 'kosher salt': 18, 'salt and pepper to taste': 18, 'optional': 18, 'red onion': 18, 'fresh peaches': 17, 'coconut': 17, 'fresh lime juice': 17, 'persimmon pulp': 17, 'granny smith apples -': 16, 'cooking spray': 16, 'apple cider vinegar': 16, 'garlic powder': 16, 'canola oil': 16, 'cold water': 15, 'fresh blueberries': 15, 'almonds': 15, 'apricot preserves': 15, 'pomegranate juice': 15, 'chicken broth': 14, 'fresh parsley': 14, 'shortening': 14, 'grated orange zest': 14, 'tomatoes': 14, 'ripe bananas': 14, 'lightly': 13, 'and thinly': 13, 'walnuts optional': 13, 'mayonnaise': 13, 'jar maraschino cherries': 13, 'maraschino cherries': 13, 'pineapple juice': 13, 'red pepper flakes': 13, 'pinch ground cinnamon': 13, 'plums': 13, 'avocados -': 13, 'thinly apples': 12, 'container frozen whipped topping': 12, 'garlic': 12, 'red bell pepper': 12, 'sifted all-purpose flour': 11, 'carrots': 11, 'sea salt': 11, 'unsweetened cocoa powder': 11, 'boneless chicken breast halves': 11, 'maple syrup': 11, 'egg whites': 11, 'lemons': 11, 'cucumber': 11, 'pomegranate seeds': 11, 'avocado': 11, 'nectarines': 11, 'green onions': 10, 'golden raisins': 10, 'whole milk': 10, 'coconut oil': 10, 'light brown sugar': 10, 'chili powder': 10, 'fresh pineapple -': 10, 'egg yolks': 10, 'fresh pineapple': 10, 'mango': 10, 'mango -': 10, 'cold butter': 9, 'cranberries': 9, 'curry powder': 9, 'raisins optional': 9, 'celery': 9, 'dried thyme': 9, 'half-pint canning jars with lids and rings': 9, 'can pineapple chunks': 9, 'semisweet chocolate chips': 9, 'white vinegar': 9, 'can coconut milk': 9, 'slivered almonds': 9, 'freshly ground black pepper': 9, 'fresh mint': 9, 'seedless watermelon': 9, 'cider vinegar': 9, 'blue cheese': 9, 'jalapeno pepper': 9, 'ketchup': 9, 'self-rising flour': 9, 'fresh peaches -': 9, 'and pears': 9, 'kiwis': 9, 'and /-inch thick': 8, 'ground black pepper to taste': 8, '. package yellow cake mix': 8, 'hot water': 8, 'can pineapple with juice': 8, 'chia seeds': 8, 'stemmed and': 8, 'blueberries': 8, 'dark brown sugar': 8, 'limes': 8, 'red wine vinegar': 8, 'plain yogurt': 8, 'fresh ginger root': 8, 'paprika': 8, 'sheet frozen puff pastry': 7, 'egg white': 7, 'cinnamon sticks': 7, 'whole cloves': 7, 'stalks celery': 7, 'carrot': 7, 'inch pie shell': 7, 'dried rosemary': 7, 'cinnamon sugar': 7, 'vanilla': 7, 'vanilla sugar': 7, 'apple -': 7, 'and finely': 7, 'and coarsely': 7, 'dijon mustard': 7, 'brandy': 7, 'heavy whipping cream': 7, 'frozen strawberries': 7, 'package ...

# %%
recipe_data = pd.read_csv("data/recipes.csv")

# %%
word_frequency = Counter(word_bank)
word_frequency
# Out:
# Counter({'butter': 320,
#          'granny smith apples or other firm': 4,
#          'crisp apples': 4,
#          'sugar': 29,
#          'dried cranberries': 21,
#          'sheet frozen puff pastry': 7,
#          'egg white': 7,
#          'small granny smith apples': 4,
#          'unsalted butter': 59,
#          'white sugar': 587,
#          'packed brown sugar': 57,
#          'water': 179,
#          'ground cinnamon': 257,
#          'baking powder': 145,
#          'baking soda': 134,
#          'lemon juice': 104,
#          'cornstarch': 65,
#          'salt': 296,
#          'ground nutmeg': 86,
#          'brown sugar': 128,
#          'cold butter': 9,
#          'fluid bottle apple cider': 4,
#          'cinnamon sticks': 7,
#          'whole allspice': 4,
#          'whole cloves': 7,
#          'cranberries': 9,
#          'large granny smith apples': 4,
#          'vanilla extract': 202,
#          "confectioners' sugar": 31,
#          'milk': 134,
#          'large tart apples': 5,
#          'wooden chopsticks for handles': 4,
#          'can sweetened condensed milk': 19,
#          'light corn syrup': 6,
#          'onion': 35,
#          'stalks celery': 7,
#          'carrot': 7,
#          'curry powder': 9,
#          'chicken broth': 14,
#          'apple': 6,
#          'white rice': 4,
#          'pinch dried thyme': 4,
#          'salt and ground black pepper to taste': 41,
#          'heavy cream': 22,
#          'cold water': 15,
#          'large apples': 4,
#          'to cover': 4,
#          'ground allspice': 27,
#          'drops yellow food coloring': 4,
#          'apples': 26,
#          'lemon juice optional': 4,
#          'raisins optional': 9,
#          'walnuts optional': 13,
#          'inch pie shell': 7,
#          'wooden craft sticks': 4,
#          'cooking spray': 16,
#          'unwrapped': 4,
#          'vegetable oil': 83,
#          'eggs': 126,
#          'white bread': 5,
#          'whole wheat bread': 5,
#          'ground turkey sausage': 5,
#          'celery': 9,
#          'dried sage': 6,
#          'dried rosemary': 7,
#          'dried thyme': 9,
#          'golden delicious apple': 5,
#          'fresh parsley': 14,
#          'cooked turkey liver': 5,
#          'turkey stock': 5,
#          'or more if needed optional': 4,
#          'prepared pie dough': 4,
#          'cut into pieces': 6,
#          'egg': 67,
#          'unsweetened apple juice': 5,
#          'apple cider vinegar': 16,
#          'ground cloves': 33,
#          'large eggs': 55,
#          'cinnamon sugar': 7,
#          'can apple pie filling': 4,
#          'margarine': 32,
#          'vanilla': 7,
#          'vanilla sugar': 7,
#          'mayonnaise': 13,
#          'walnuts': 67,
#          'pinch salt': 34,
#          'ground black pepper to taste': 8,
#          'applesauce': 5,
#          'ground mustard': 1,
#          'carrots': 11,
#          'raisins': 27,
#          'unsweetened flaked coconut': 2,
#          'rolled oats': 26,
#          'tart apple': 1,
#          'large egg': 27,
#          'pecans': 45,
#          'large red apple': 1,
#          "confectioners' sugar optional": 1,
#          'soft bread cubes': 1,
#          'and apples': 4,
#          'inch frozen pie crust': 1,
#          'aluminum foil': 3,
#          'tart green apples': 1,
#          'ground ginger': 26,
#          'ground beef': 6,
#          'dry bread crumbs': 4,
#          'garlic powder': 16,
#          'ground black pepper': 39,
#          'inch un pie crusts': 1,
#          'shortening': 14,
#          'chilled': 4,
#          'nutmeg': 2,
#          'inch refrigerated prerolled pie crusts': 1,
#          'cut into small chunks': 3,
#          'golden delicious apples': 1,
#          'package powdered fruit pectin': 2,
#          'cabbage': 2,
#          'un red apple': 1,
#          'un granny smith apple': 1,
#          'grated': 4,
#          'green onions': 10,
#          'golden raisins': 10,
#          'sea salt': 11,
#          'and into eighths': 1,
#          'medium sweet onions': 1,
#          'fresh thyme': 6,
#          'dijon mustard': 7,
#          'chicken stock': 5,
#          'lukewarm milk': 1,
#          'dried currants': 4,
#          "confectioners' sugar for dusting": 2,
#          'orange juice': 28,
#          'bing or other dark': 1,
#          'sweet cherries': 2,
#          'rinsed and or use frozen cherries': 1,
#          'vanilla bean ice cream': 1,
#          'cherry extract': 1,
#          'brandy': 7,
#          'sour cherries': 3,
#          'tart red cherries': 2,
#          'candied mixed fruit': 1,
#          'glace cherries': 1,
#          'candied mixed citrus peel': 1,
#          'sugar cube': 2,
#          'dash bitters': 2,
#          'fluid whiskey rye or bourbon': 2,
#          'lemon twist': 2,
#          'ice cubes': 27,
#          'orange slice': 2,
#          'maraschino cherry': 6,
#          'cooking spray with flour': 2,
#          'can pineapple rings': 2,
#          'jar maraschino cherries': 13,
#          'whole milk': 10,
#          'stick butter': 4,
#          'can pineapple': 25,
#          'jar cherries': 2,
#          'maraschino cherries with stems': 1,
#          'corn syrup': 1,
#          "sifted confectioners' sugar": 4,
#          "chocolate confectioners' coating": 1,
#          'friendship fruit starter': 2,
#          'can peaches with juice': 2,
#          'can pineapple chunks with juice': 2,
#          'jars maraschino cherries': 2,
#          'flaked coconut': 33,
#          'round steak': 1,
#          'cut into small pieces': 3,
#          'apple cider': 1,
#          'candied mixed fruit peel': 4,
#          'jar sour cherry preserves': 1,
#          'can sour cherries': 1,
#          'with liquid reserved': 1,
#          'recipe pastry for a inch double crust pie': 6,
#          'boiling water': 21,
#          'dry mustard powder': 3,
#          'honey': 56,
#          'fresh lemon juice': 26,
#          'can pineapple chunks': 9,
#          'toothpicks': 3,
#          'almond extract': 22,
#          'fresh and sweet cherries': 1,
#          'fresh peaches': 17,
#          'with juice reserved': 6,
#          'tart cherries such as door county cherries': 1,
#          'vodka': 3,
#          'or inch white cake layers': 1,
#          'and cooled': 1,
#          'fresh strawberries': 26,
#          'fresh blueberries': 15,
#          'bananas': 27,
#          'heavy whipping cream': 7,
#          'blanched slivered almonds': 3,
#          'maraschino cherries': 13,
#          'banana': 26,
#          'frozen strawberries': 7,
#          'frozen blueberries': 3,
#          'frozen cherries': 1,
#          'vanilla yogurt': 6,
#          'honey optional': 1,
#          'cherries': 4,
#          'salted butter': 1,
#          'cut into bits': 1,
#          'clementine oranges': 1,
#          'cinnamon stick': 2,
#          'bitters': 1,
#          'ice': 18,
#          'fluid rye whiskey': 1,
#          'fluid benedictine liqueur': 1,
#          "dashes aromatic bitters such as peychaud's®": 1,
#          'cans cherry pie filling': 1,
#          'unsweetened cocoa powder': 11,
#          'sweetened condensed milk': 3,
#          'semisweet chocolate chips': 9,
#          'dried cherries': 6,
#          'hot water': 8,
#          'container vanilla yogurt': 1,
#          'kosher salt': 18,
#          'large egg yolk': 2,
#          'fresh cherries': 3,
#          'packages powdered fruit pectin': 1,
#          'half canning jars with lids and rings': 2,
#          'cooked': 2,
#          'boneless chicken breast halves': 11,
#          'buttermilk': 20,
#          'apples optional': 1,
#          'vanilla bean': 3,
#          'split optional': 1,
#          'cherries with pits': 1,
#          'olive oil': 78,
#          'container plain yogurt': 2,
#          'dates': 28,
#          'cornflakes cereal': 2,
#          'white vinegar': 9,
#          'jar cherry preserves': 1,
#          'candied cherries': 4,
#          'can coconut milk': 9,
#          'package vanilla wafers': 3,
#          'pits removed and cut in half': 1,
#          'can cherry pie filling': 3,
#          'red candied cherries': 1,
#          'can pineapple with juice': 8,
#          'package cream cheese': 24,
#          'sherry wine or marsala': 1,
#          'almond macaroon crumbs': 1,
#          'ground almonds': 3,
#          'red maraschino cherries': 1,
#          'green maraschino cherries': 1,
#          'slivered almonds': 9,
#          'ground cherries': 1,
#          'blanched almond flour': 3,
#          'and dates': 2,
#          'chia seeds': 8,
#          'coconut oil': 10,
#          'maple syrup': 11,
#          'sifted cake flour': 3,
#          'egg whites': 11,
#          'drops red food coloring': 2,
#          'with stems': 1,
#          'juice reserved': 2,
#          'inch prepared graham cracker crust': 2,
#          'frozen whipped topping': 2,
#          'inch un pie crust see footnote for recipe link': 1,
#          'light brown sugar': 10,
#          'cold': 1,
#          'lemon': 36,
#          'cocoa powder': 2,
#          'maraschino cherry juice': 1,
#          'pineapple juice': 13,
#          'miniature colored marshmallows': 1,
#          'graham crackers': 3,
#          'stems removed': 4,
#          'whole chicken': 3,
#          'salt and pepper to taste': 18,
#          'can dark cherries packed in water': 1,
#          'inch pie crust': 3,
#          'container frozen whipped topping': 12,
#          'chocolate sandwich cookies with creme filling': 1,
#          'packages cream cheese': 7,
#          'baking cocoa': 1,
#          'whipped topping': 2,
#          'fresh figs': 24,
#          'herbed goat cheese chevre': 1,
#          'almonds': 15,
#          'balsamic vinegar': 26,
#          'arugula': 3,
#          'grated parmesan cheese': 4,
#          'pine nuts': 6,
#          'frozen bananas': 1,
#          'fresh ripe figs': 1,
#          'large red onion': 3,
#          'fresh black mission figs': 2,
#          'aged balsamic vinegar': 3,
#          'stemmed and': 8,
#          'flax seed meal': 1,
#          'pumpkin pie spice': 2,
#          'boneless chicken thighs': 3,
#          'large shallot': 1,
#          'lengthwise': 3,
#          'fresh rosemary': 3,
#          'mission figs': 1,
#          'stemmed': 4,
#          'grated fresh ginger': 4,
#          'pouches liquid pectin such as certo®': 1,
#          'nonstick cooking spray': 2,
#          'fresh fig slices': 1,
#          'optional': 18,
#          'golden brown sugar': 1,
#          'prosciutto': 1,
#          'leaves fresh basil': 3,
#          'cut into thin strips': 3,
#          'evaporated milk': 7,
#          'blueberries': 8,
#          'lime juice': 26,
#          'torn romaine lettuce': 1,
#          'large ripe but firm pear': 1,
#          'gruyere cheese': 1,
#          'small red onion': 6,
#          'currants': 1,
#          'creme de cassis liqueur': 1,
#          'ground coriander': 6,
#          'boneless leg of lamb': 2,
#          'rolled and tied': 1,
#          'roasted and salted almonds': 1,
#          'fresh mint': 9,
#          'cloves garlic': 42,
#          'cut into thirds': 1,
#          'stemmed calimyrna figs': 1,
#          'fresh basil': 3,
#          'leaves mint': 1,
#          'leaves basil': 1,
#          'dried mission figs': 2,
#          'bourbon whiskey': 2,
#          'chicken tenders': 1,
#          'whole wheat pastry flour': 1,
#          'canola oil': 16,
#          'black mission figs': 3,
#          'extra virgin olive oil': 5,
#          'burrata cheese': 2,
#          'sea salt and ground black pepper to taste': 1,
#          'canned figs with juice': 1,
#          'cut in half': 2,
#          'goat cheese': 7,
#          'slices prosciutto': 1,
#          'trimmed of all fat and cut into strips': 1,
#          'heads romaine lettuce': 1,
#          'pith removed': 1,
#          'and cut into segments': 1,
#          'gorgonzola cheese': 3,
#          'vinaigrette dressing': 1,
#          'ground white pepper': 4,
#          'cranberry juice': 1,
#          'strawberries': 22,
#          'watermelon chunks': 1,
#          'french baguette': 1,
#          'container ricotta cheese': 1,
#          'fresh basil leaves': 3,
#          'cut in quarters': 1,
#          'vegetable broth': 1,
#          'green onion': 5,
#          'package arborio rice': 1,
#          'dry white wine': 4,
#          'small fresh figs': 1,
#          'thin slices prosciutto': 3,
#          'dark brown sugar': 8,
#          'maple extract': 1,
#          'package fresh cranberries': 3,
#          'inch fresh rosemary sprig': 1,
#          'shallots': 6,
#          'clove garlic': 22,
#          'soft goat cheese': 1,
#          'mozzarella cheese': 3,
#          'figs': 1,
#          'large': 1,
#          'lemon zest': 19,
#          'lemon pepper seasoning': 1,
#          'whiskey': 1,
#          'cream of tartar': 5,
#          'large yellow onion': 1,
#          'cut into thin slices': 1,
#          'small dried mission figs': 1,
#          'crackers': 1,
#          'orange blossom water': 2,
#          'grated orange zest': 14,
#          'dried figs': 1,
#          'red wine': 1,
#          'red pepper flakes': 13,
#          'pork chops': 2,
#          'frozen cranberries': 2,
#          'canned figs': 1,
#          'apple juice': 3,
#          'peaches': 4,
#          'white wine': 6,
#          'vanilla yogurt such as dannon® light and fit®': 1,
#          'cantaloupe': 5,
#          'watermelon': 24,
#          'large seedless watermelon': 1,
#          'tomatoes': 14,
#          'feta cheese': 7,
#          'large sweet onion': 3,
#          'mint leaves': 2,
#          'white balsamic vinegar': 6,
#          'pinch coarse salt': 1,
#          'pinch ground black pepper': 1,
#          'lime': 25,
#          'seedless watermelon': 9,
#          'baby cucumbers': 1,
#          'red onion': 18,
#          'cut lengthwise': 1,
#          'english cucumber': 1,
#          'package feta cheese': 2,
#          'fresh cilantro': 38,
#          'cracked black pepper': 1,
#          'basil leaves': 2,
#          'chili powder': 10,
#          'ground cumin': 19,
#          'cayenne pepper': 7,
#          'dash salt': 1,
#          'chilled heavy cream': 1,
#          'sprigs fresh basil': 1,
#          'small watermelon': 1,
#          'fruit removed with a melon baller': 1,
#          'package fresh mozzarella cheese': 1,
#          'baby spinach leaves': 1,
#          'grape tomatoes': 3,
#          'bite sized watermelon chunks': 1,
#          'strips orange zest': 1,
#          'white tequila': 1,
#          'pinch salt or sugar for rimming glasses': 1,
#          'large chilled seedless watermelon': 1,
#          'fresh mint leaves': 3,
#          'limes': 8,
#          'fluid can evaporated milk': 6,
#          'coconut': 17,
#          'large fresh peaches': 4,
#          'large nectarines': 3,
#          'red anjou pear': 3,
#          'seedless grapes': 7,
#          'lemons': 11,
#          'fresh mint chocolate mint preferred': 3,
#          'honey fireweed honey preferred': 3,
#          'and optional': 5,
#          'and watermelon': 1,
#          'red wine vinegar': 8,
#          'ground pepper': 1,
#          'to taste': 3,
#          'spring mix': 1,
#          'log montchevre® honey goat cheese': 1,
#          'hazelnuts': 2,
#          'large watermelon': 1,
#          'honeydew melon': 3,
#          'cans mandarin oranges': 5,
#          'cans pineapple chunks': 1,
#          'grated lemon zest': 5,
#          'cucumbers': 1,
#          'trimmed and': 1,
#          'fresh lime juice': 17,
#          'black olive halves': 1,
#          'watermelon rind': 2,
#          'spearmint leaves': 1,
#          'dried sweet basil': 1,
#          'tequila': 1,
#          'orange liqueur': 2,
#          'cider vinegar': 9,
#          'inch cinnamon stick': 1,
#          'slices cantaloupe': 1,
#          'cucumber': 11,
#          'wedge fresh lime': 1,
#          'ice as needed': 1,
#          'slices watermelon': 1,
#          'slices lime': 1,
#          'and pureed': 2,
#          'egg yolks': 10,
#          'butter flavored extract': 2,
#          'fresh baby spinach': 1,
#          'torn': 2,
#          'walnut oil': 3,
#          'sweet paprika': 2,
#          'light olive oil': 2,
#          'small sweet onion such as vidalia®': 1,
#          'blue cheese': 9,
#          'green bell pepper': 5,
#          'jalapeno pepper': 9,
#          'garlic salt': 3,
#          'english seedless cucumber': 1,
#          'small onion': 3,
#          'and strawberries': 1,
#          'and kiwi': 1,
#          'sprigs fresh mint': 1,
#          'gin': 1,
#          'tonic water': 1,
#          'slice watermelon': 1,
#          'rind removed': 1,
#          'fluid vodka such as absolut®': 1,
#          'fluid lemon juice': 2,
#          'fresh orange juice': 2,
#          'fluid gin': 2,
#          'fluid simple syrup': 1,
#          'fluid club soda': 2,
#          'lemon wedge': 1,
#          'cornish game hens': 1,
#          'sprigs fresh rosemary': 5,
#          'garlic': 12,
#          'large sea scallops': 1,
#          'pepper': 2,
#          'potatoes': 1,
#          'and cut into thick wedges': 1,
#          'oregano': 1,
#          'oil': 1,
#          'chicken wings': 1,
#          'medium lemons': 1,
#          'pinch garlic powder': 1,
#          'pinch paprika': 1,
#          'slices lemon': 2,
#          'sprigs fresh parsley': 1,
#          'dried oregano': 7,
#          'unsweetened pineapple juice': 5,
#          'package acini di pepe pasta': 3,
#          'cans pineapple tidbits': 3,
#          'miniature marshmallows': 3,
#          'lobster tails': 1,
#          'wedges lemon': 1,
#          'mackerel fillets': 1,
#          'ground paprika': 2,
#          'soy sauce': 19,
#          'fish sauce': 6,
#          'chicken thighs': 1,
#          'pounded to an even thickness': 1,
#          'fluid triple sec liqueur': 1,
#          'valencia oranges': 1,
#          'slice orange': 1,
#          'fine salt': 2,
#          'frozen unsalted butter': 2,
#          'large egg yolks': 3,
#          'can mandarin orange segments': 1,
#          'cloves cloves garlic': 2,
#          'or pressed through a garlic press': 1,
#          'salmon fillet': 2,
#          'flour': 2,
#          'raspberries': 3,
#          'oranges': 2,
#          'orzo pasta': 1,
#          'medium carrots': 1,
#          'ribs celery': 1,
#          'medium onion': 3,
#          'bay leaf': 2,
#          'cooked chicken breast': 1,
#          'package baby spinach leaves': 1,
#          'grated parmesan cheese optional': 1,
#          'chicken soup base': 1,
#          'cooked white rice': 1,
#          'cooked chicken meat': 2,
#          'fresh lemon zest': 1,
#          'powdered sugar': 3,
#          'can mandarin oranges': 3,
#          'cottage cheese': 1,
#          'ketchup': 9,
#          'olive oil cooking spray': 1,
#          'and deveined bay shrimp': 1,
#          'pinch garlic salt': 1,
#          'cold unsalted butter': 3,
#          'capers': 1,
#          'lemon wedges': 1,
#          'backbone removed': 1,
#          'kosher salt and ground black pepper to taste': 2,
#          'into rounds': 1,
#          'packages refrigerated crescent roll dough such as pillsbury® recipe creations®': 1,
#          'fillets orange roughy': 1,
#          'orange': 6,
#          'lemon pepper': 1,
#          'large eggplant': 1,
#          'dried tarragon': 1,
#          'white pepper': 3,
#          'lemon extract': 4,
#          "confectioners' sugar for decoration": 3,
#          'salmon fillets': 1,
#          'bones and skin removed': 1,
#          'coarse salt to taste': 1,
#          'bunch swiss chard': 1,
#          'stems and center ribs cut out and together': 1,
#          'pinch salt to taste': 1,
#          'shortbread cookie crumbs': 1,
#          'large cloves fresh garlic': 1,
#          'light': 1,
#          'water to adjust texture': 1,
#          'vinegar': 6,
#          'chicken bouillon granules': 1,
#          'ripe pears': 2,
#          'powdered fruit pectin': 2,
#          'flounder fillets': 1,
#          'cans peaches in heavy syrup': 2,
#          'original bisquick® mix': 1,
#          'butter or margarine': 5,
#          'can peaches': 7,
#          'of fresh peaches or nectarines': 1,
#          'or whole blueberries': 1,
#          'package dry pectin': 1,
#          'and peaches': 2,
#          'sheets refrigerated pie crust': 1,
#          'frozen peaches': 1,
#          'coarse sparkling sugar': 1,
#          'and syrup reserved': 1,
#          'fresh clingstone peaches': 1,
#          'blanched and': 1,
#          'inch cinnamon sticks': 2,
#          'packages frozen peachessuch as cascadian farm®': 1,
#          'package frozen blueberriessuch as cascadian farm®': 1,
#          'cans peaches in juice': 1,
#          'cans peaches': 1,
#          'can refrigerated buttermilk biscuit dough such as pillsbury grands!®': 1,
#          'pinch ground cinnamon': 13,
#          'pinch white sugar': 2,
#          'pinch ground nutmeg': 5,
#          'bottles moscato wine': 3,
#          'peach schnapps': 4,
#          'package fresh strawberries': 3,
#          'container fresh raspberries': 4,
#          'can peaches in light syrup': 1,
#          'and cut into eighths': 2,
#          'ripe peaches': 1,
#          'scoops vanilla ice cream': 1,
#          'and fresh peaches': 1,
#          'fresh blackberries': 4,
#          'minute tapioca': 1,
#          'dash dash of nutmeg': 1,
#          'plain yogurt': 8,
#          'cubes ice': 4,
#          'packed light brown sugar': 6,
#          'can canned peaches': 1,
#          'ground cinnamon optional': 3,
#          'package yellow cake mix': 2,
#          'skinned': 2,
#          'recipe pastry for a inch single crust pie': 3,
#          'can peaches in heavy syrup': 2,
#          'un': 2,
#          'into pats': 1,
#          'or more if needed': 2,
#          'french bread': 1,
#          'torn into small pieces': 1,
#          'flaked salt': 1,
#          'large heirloom tomatoes': 2,
#          'and into half moons': 1,
#          'ball fresh mozzarella': 1,
#          'package frozen peach slices': 1,
#          'brown sugar substitute': 1,
#          'instant hot chocolate mix': 1,
#          'vanilla ice cream': 4,
#          'mangos': 5,
#          'small peaches': 2,
#          'fresh pineapple': 10,
#          'white onion': 7,
#          'red bell pepper': 12,
#          'yellow bell pepper': 2,
#          'small jalapeno pepper': 2,
#          'slices fresh peach': 1,
#          'preserved ginger': 1,
#          'mustard seed': 1,
#          'pickling spice': 1,
#          'firm pears': 1,
#          'good quality bourbon whiskey': 1,
#          'inch pie crust pastry': 2,
#          'sour cream': 19,
#          'cans pears': 1,
#          'inch graham cracker crust': 1,
#          'shortcrust pastry crust': 1,
#          '% dark chocolate': 1,
#          'superfine sugar': 3,
#          'inch un pie crust': 4,
#          'and cut in half': 1,
#          'cream cheese': 4,
#          'ground cardamom': 3,
#          'apricot jam': 3,
#          'warmed': 1,
#          'cheddar cheese': 7,
#          'unfolded': 1,
#          'bartlett pears': 3,
#          "d'anjou pears": 1,
#          'red pear': 1,
#          'turbinado sugar': 4,
#          'large pears': 2,
#          'grated nutmeg': 1,
#          'inch un single pie crust': 1,
#          'coarse granulated sugar': 1,
#          'dark chocolate chips optional': 1,
#          'reynolds® parchment paper': 1,
#          'reynolds wrap® aluminum foil': 2,
#          'milk chocolate': 1,
#          'split lengthwise': 1,
#          'pods cardamom': 1,
#          'inch un tart shells': 1,
#          'and pears': 9,
#          'inch un pie shell': 2,
#          'and plums': 5,
#          'grated fresh ginger root': 1,
#          'white granulated sugar': 1,
#          'fine sea salt': 1,
#          'frozen': 2,
#          'for egg wash': 1,
#          'sheet reynolds wrap® aluminum foil': 1,
#          'sheet reynolds® parchment paper': 1,
#          'pears': 4,
#          'butternut squash': 1,
#          'fresh ginger root': 8,
#          'reduced sodium chicken broth': 1,
#          'firm ripe bartlett pears': 1,
#          'and cut into inch dice': 1,
#          'half and half': 1,
#          'medium pears': 1,
#          'thick slices french bread': 1,
#          'thin slices brie cheese': 1,
#          'fresh thyme leaves': 1,
#          'pinch cracked black pepper': 2,
#          'slices pear such as bosc': 1,
#          'salt to taste': 19,
#          'large onions': 3,
#          'large green bell peppers': 1,
#          'jalapeno peppers': 2,
#          'prepared mustard': 2,
#          'canning jars with lids and rings': 1,
#          'dried mixed fruit': 1,
#          'bag mixed field greens': 1,
#          'red onion optional': 1,
#          'bosc pear': 2,
#          'candied pecans': 2,
#          'pear': 1,
#          'package mixed baby greens': 1,
#          'poppy seeds': 4,
#          'head romaine lettuce': 2,
#          'swiss cheese': 2,
#          'cashews': 2,
#          'package refrigerated pizza crust dough': 1,
#          'provolone cheese': 1,
#          'fresh chives': 2,
#          'white wine vinegar': 5,
#          'walnut pieces': 2,
#          'stems left on': 1,
#          'prepared hot fudge topping': 1,
#          'and apple': 2,
#          'mixed baby greens': 1,
#          'havarti cheese': 1,
#          'penne pasta': 1,
#          'large pear': 2,
#          'plums': 13,
#          'apricot preserves': 15,
#          'dry mustard': 1,
#          'whole wheat flour': 5,
#          'fresh bread crumbs': 1,
#          'suet': 1,
#          'small carrot': 1,
#          'blanched almonds': 1,
#          'preserved stem ginger in syrup': 1,
#          'mixed spice': 1,
#          'ale': 1,
#          'tapioca': 1,
#          'prunes': 7,
#          'dark corn syrup': 1,
#          'and cut into small chunks': 1,
#          'medium italian plums': 1,
#          'black or red plums': 1,
#          'proof vodka': 1,
#          'orange peel in pieces': 1,
#          'pork tenderloin': 3,
#          'fresh thyme sprigs': 1,
#          'firm plums': 1,
#          'and each cut into wedges': 1,
#          'italian plums': 1,
#          'italian prune plums': 5,
#          'black plums': 1,
#          'cumin': 4,
#          'slivered almonds optional': 1,
#          'boneless pork chops': 4,
#          'large clove garlic': 1,
#          'fresh plums': 2,
#          'puff pastry rectangles': 1,
#          'large potatoes': 1,
#          'fresh damson or damask plums': 1,
#          'whole cardamom pods': 1,
#          'and pear': 1,
#          'and cherries': 1,
#          'dried prunes': 1,
#          'sugar substitute such as splenda': 1,
#          'oat bran': 1,
#          'ripe bananas': 14,
#          'red plums': 1,
#          'fluid can frozen orange juice concentrate': 1,
#          'warm water': 2,
#          'bread flour': 2,
#          'bread machine yeast': 1,
#          'large russet potatoes': 1,
#          'farina': 1,
#          'cubes white sugar': 1,
#          'additional butter and sugar optional': 1,
#          'pinches salt': 1,
#          'almonds optional': 1,
#          'rum': 2,
#          'and fresh prune plums': 1,
#          'onions': 3,
#          'malt vinegar': 1,
#          'worcestershire sauce': 6,
#          'ground cayenne pepper': 1,
#          'blueberry juice optional': 1,
#          'stick unsalted butter': 1,
#          'extra large eggs': 1,
#          'medium ripe plums': 1,
#          'can stewed prunes': 1,
#          'very ripe plums': 1,
#          'pressed': 1,
#          'southwest chipotle seasoning': 1,
#          'roasted garlic seasoning': 1,
#          'liquid smoke flavoring': 1,
#          'dried apricots': 19,
#          'boneless pork loin roast': 2,
#          'butterflied': 2,
#          'mustard powder': 3,
#          'water optional': 1,
#          'hot water optional': 1,
#          'seedless green grapes': 2,
#          'strong brewed black tea': 1,
#          'compressed fresh yeast': 1,
#          'plum jam': 1,
#          'grated fresh lemon peel': 1,
#          'if needed': 1,
#          'cinnamon': 4,
#          'zucchini': 2,
#          'bag baby spinach leaves': 1,
#          'rinsed and': 4,
#          'feta': 1,
#          'medium red onion': 3,
#          'very thin': 1,
#          'alfalfa sprouts optional': 1,
#          'pomegranate seeds': 11,
#          'balsamic vinaigrette': 1,
#          'poblano peppers': 1,
#          'leafy salad green mix': 1,
#          'cranberry vinaigrette': 1,
#          'pomegranate': 6,
#          'fluid vodka': 1,
#          'fluid pomegranate juice': 1,
#          'pomegranate juice': 15,
#          'fluid container liquid pectin': 1,
#          'lamb shoulder blade chops': 1,
#          'pumpkin seeds': 2,
#          'dark soy sauce': 1,
#          'pomegranate molasses': 1,
#          'sunflower seed oil': 1,
#          'smooth mustard': 1,
#          'rice vinegar': 7,
#          'kosher salt to taste': 1,
#          'hot vegetable broth': 1,
#          'saffron threads': 2,
#          'pinch ground allspice': 1,
#          'unsalted shelled pistachios': 1,
#          'large pomegranate': 2,
#          'and seeds separated': 5,
#          'green leaf lettuce': 1,
#          'rinsed and torn': 1,
#          'bartlett or anjou pear': 1,
#          'skim milk': 2,
#          'granular sucralose sweetener such as splenda®': 1,
#          'sprigs fresh mint leaves optional': 1,
#          'sticks unsalted butter': 1,
#          'fuyu persimmon': 4,
#          'orange blossom water optional': 2,
#          'fluid orange juice': 1,
#          'fluid champagne': 1,
#          'bag fresh cranberries': 1,
#          'rinsed and sorted': 2,
#          'orange zest': 3,
#          'chicken legs': 1,
#          'cut up': 1,
#          'cardamom optional': 1,
#          'sugar optional': 1,
#          'pomegranates': 2,
#          'fl bottle pomegranate juice': 1,
#          'large oranges': 1,
#          'bags fresh cranberries': 1,
#          'seeds removed and reserved': 1,
#          'shallot': 4,
#          'smoked paprika': 1,
#          'chipotle chile powder': 3,
#          'fresh ginger': 4,
#          'fresh brussels sprouts': 1,
#          'and separated into leaves': 1,
#          'almond milk': 3,
#          'seeds of pomegranate': 1,
#          'halloumi cheese': 1,
#          'pomegranate vinegar': 1,
#          'harissa': 1,
#          'black beans': 1,
#          'and rinsed': 5,
#          'kidney beans': 1,
#          'white beans': 1,
#          'fillets salmon': 1,
#          'medium granny smith apples': 1,
#          'package baby spinach': 1,
#          'shiraz or other dry red wine': 1,
#          'pomegranates with the seeds removed': 1,
#          'champagne vinegar': 1,
#          'fresh cracked pepper': 1,
#          'freekeh': 1,
#          'tahini': 1,
#          'pistachios': 1,
#          'fresh baby spinach leaves': 1,
#          'arugula leaves': 1,
#          'medium red onions': 1,
#          'medium butternut squash': 1,
#          'saffron powder': 1,
#          'raw macadamia nuts': 2,
#          'small potato': 1,
#          'fresh pomegranate seeds': 1,
#          'cut into matchsticks': 3,
#          'quinoa': 2,
#          'cube vegetable bouillon': 1,
#          'broccoli florets': 1,
#          'kale': 1,
#          'honeycrisp apples': 1,
#          'dressing:': 1,
#          'pinch red pepper flakes': 3,
#          'serrano chile peppers': 1,
#          'ripe avocados': 1,
#          'sprig cilantro': 1,
#          'persimmon pulp': 17,
#          'persimmon flesh': 1,
#          'persimmon skin': 1,
#          'ripe persimmons': 3,
#          'pureed': 3,
#          'ripe fuyu persimmons': 2,
#          'medium lemon': 1,
#          'agave syrup': 1,
#          'persimmon puree': 1,
#          'hachiya persimmon': 1,
#          'pureed persimmons': 2,
#          'persimmons': 1,
#          'hachiya persimmons': 1,
#          'pulp extracted': 1,
#          'chocolate chips': 2,
#          'overripe fuyu persimmons': 1,
#          'small granny smith apple': 1,
#          'large ripe persimmons': 1,
#          'stem removed and into rounds': 1,
#          'ball burrata cheese': 1,
#          'balsamic glaze': 1,
#          'ripe hachiya persimmon pulp': 2,
#          'fresh cranberries': 3,
#          'canned sweetened condensed milk': 1,
#          'yellow onion': 1,
#          'can seasoned tomatoes': 1,
#          'can tomatoes with jalapeno peppers': 1,
#          'can pinto beans': 2,
#          'can kidney beans': 2,
#          'can black beans': 2,
#          'can chicken broth': 1,
#          'can chili with beans optional': 1,
#          'tangy coconut and chili vindaloo sauce such as maya kaimal®': 1,
#          'tomato paste': 5,
#          'ripe persimmon': 1,
#          'leaves stripped': 1,
#          'wheat flour': 1,
#          'oatmeal': 1,
#          'very ripe persimmon pulp': 1,
#          'wheat germ': 2,
#          'active dry yeast': 2,
#          'packed': 1,
#          'fuyu persimmons': 2,
#          'raisin paste': 1,
#          'well': 1,
#          'into small pieces': 1,
#          'agave nectar': 3,
#          'green chile pepper': 2,
#          'ground coriander seed': 1,
#          'cake flour': 1,
#          'large bananas': 1,
#          'peanut butter': 5,
#          'medium bananas': 1,
#          'and lengthwise and crosswise': 1,
#          'inch pastry shell': 1,
#          'cooled': 1,
#          'overripe bananas': 1,
#          'bananas ripe or very ripe work best': 1,
#          'yogurt': 3,
#          'package instant vanilla pudding mix': 2,
#          'cold skim milk': 1,
#          'soy milk': 2,
#          'white sugar optional': 3,
#          'vanilla extract optional': 4,
#          'very ripe bananas': 3,
#          'container sour cream': 3,
#          'plain soy milk': 1,
#          'packed fresh spinach leaves': 1,
#          'large banana': 3,
#          'graham cracker crumbs': 5,
#          'peanuts': 4,
#          'large very ripe bananas': 1,
#          'mini semisweet chocolate chips': 1,
#          'coconut milk': 4,
#          'pineapple or apple juice': 2,
#          'avocado oil cooking spray': 1,
#          'package vanilla wafer cookies': 1,
#          'canned pumpkin puree': 1,
#          'walnut pieces optional': 1,
#          ...})

# %%
common_ingredients = word_frequency.most_common()[:10]
common_ingredients
# Out:
# [('white sugar', 587),
#  ('butter', 320),
#  ('salt', 296),
#  ('ground cinnamon', 257),
#  ('vanilla extract', 202),
#  ('water', 179),
#  ('baking powder', 145),
#  ('baking soda', 134),
#  ('milk', 134),
#  ('brown sugar', 128)]

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
mpl.rcParams['font.family'] = 'DejaVu Sans' # Set global font to serif
mpl.rcParams['font.size'] = 12 # Set global font size
mpl.rcParams.update({'text.color' : "black", 'axes.labelcolor' : "black"})

item = []
count = []

for ingredient in common_ingredients:
    item.append(ingredient[0])
    count.append(ingredient[1])

item.reverse()
count.reverse()

item = np.array(item)
count = np.array(count)

plt.barh(item, count)
plt.xlabel("Frequency")
plt.title("Word Frequency of Top 10 Most Common Ingredients")
plt.show()

# %%
recipe_dict = {}

for index, row in recipe_data.iterrows():
    recipe_name = row['recipe_name']

    ingredients_list = row['ingredients']
    cleaned_ingredients = clean_ingredients(ingredients_list).split(',')
    cleaned_ingredients = [ingredient.strip() for ingredient in cleaned_ingredients if ingredient.strip()]

    recipe_dict[recipe_name] = cleaned_ingredients

ingredients = 'ingredients'
ingredient_keys = [item.lower() for item in ingredients]
        
def label_diet(ingredient_list):
    ingredient_list = [str(ingredient).lower() for ingredient in ingredient_list]

    # First: check if any meat/seafood is present
    for ingredient in ingredient_list:
        if any(animal in ingredient for animal in non_vegetarian):
            return None  # Not vegetarian or vegan

    # Second: check if any animal byproduct (egg, milk, etc.) is present
    for ingredient in ingredient_list:
        if any(animal_product in ingredient for animal_product in non_vegan):
            return "vegetarian"

    # Otherwise: vegan
    return "vegan"

recipe_data['Dietary Label'] = recipe_data['ingredient_list'].apply(label_diet)
recipe_data['cleaned_ingredients'] = recipe_data['ingredient_list'].apply(clean_ingredients)

recipe_data
# Out:
# This is recipe_dict from the for loop {'Apple-Cranberry Crostada': ['butter', 'granny smith apples or other firm', 'crisp apples', 'ered', 'and /-inch thick', 'macintosh apples or other soft-textured apples that fall apart when cooked', 'ered', 'and /-inch thick', 'sugar', 'dried cranberries', 'sheet fren puff pastry', 'but still cold follow package directions', 'egg white', 'lightly', 'sugar', 'optional: ice cream or lightly sweetened whipped cream'], 'Apple Pie by Grandma Ople': ['small granny smith apples', 'unsalted butter', 'all-purpose flour', 'white sugar', 'packed brown sugar', 'water', 'inch double-crust pie pastry'], "Sarah's Homemade Applesauce": ['apples -', 'and', 'water', 'white sugar', 'ground cinnamon'], 'Apple Crisp': ['all-purpose apples', 'and', 'white sugar', 'all-purpose flour', 'ground cinnamon', 'water', 'quick-cooking oats', 'all-purpose flour', 'packed brown sugar', 'baking powder', 'baking soda', 'butter'], 'Apple Pie Filling': ['thinly apples', 'lemon juice', 'water', 'white sugar', 'cornstarch', 'ground cinnamon', 'salt', 'ground nutmeg'], 'Easy Apple Crisp with Oat Topping': ['apples -', 'and', 'white sugar', 'ground cinnamon', 'brown sugar', 'old-fashioned oats', 'all-purpose flour', 'cold butter'], 'Easy Apple Cider': ['fluid bottle apple cider', 'cinnamon sticks', 'whole allspice', 'whole cloves', 'brown sugar'], 'Apple-Cranberry Crisp': ['granny smith apples -', 'and thinly', 'cranberries', 'white sugar', 'ground cinnamon', 'ground nutmeg'], 'Old-Fashioned Apple Dumplings': ['recipe pastry for double-crust pie', 'large granny smith apples', 'and', 'butter', 'brown sugar', 'ground cinnamon', 'ground nutmeg', 'water', 'white sugar', 'vanilla extract'], 'Southern Fried Apples': ['butter', 'white sugar', 'ground cinnamon', 'granny smith apples -', 'and'], 'Apple Turnovers': ['lemon juice', 'water', 'granny smith apples -', 'and', 'butter', 'brown sugar', 'ground cinnamon', 'cornstarch', 'water', '. package fren puff pastry sheets', "confectioners' sugar", 'milk', 'vanilla extract'], 'Apple Crisp - Perfect and Easy': ['apples -', 'and', 'sifted all-purpose flour', 'white sugar', 'ground cinnamon', 'salt', 'butter'], 'The Best Caramel Apples': ['large tart apples', 'wooden chopsticks for handles', 'packed brown sugar', 'can sweetened condensed milk', 'light corn syrup', 'butter', 'vanilla extract'], 'Mulligatawny Soup': ['onion', 'stalks celery', 'carrot', 'butter', 'all-purpose flour', 'curry powder', 'chicken broth', 'apple', 'and', 'white rice', 'boneless chicken breast half -', 'pinch dried thyme', 'salt and ground black pepper to taste', 'heavy cream'], 'Sauteed Apples': ['butter', 'large tart apples -', 'and / inch thick', 'cold water', 'cornstarch', 'brown sugar', 'ground cinnamon'], 'Homemade Apple Cider': ['large apples', 'ered', 'water', 'to cover', 'white sugar', 'ground cinnamon', 'ground allspice'], 'Canned Apple Pie Filling': ['white sugar', 'cornstarch', 'ground cinnamon', 'ground nutmeg', 'water', 'salt', 'lemon juice', 'drops yellow food coloring', 'apples'], 'Easy Apple Pie': ['. package pastry for a -inch double-crust pie', 'white sugar', 'ground cinnamon', 'thinly apples', 'butter'], 'Apple Crumb Pie': ['thinly apples', 'lemon juice optional', 'white sugar', 'all-purpose flour', 'ground cinnamon', 'ground nutmeg', 'raisins optional', 'walnuts optional', 'inch pie shell', 'all-purpose flour', 'packed brown sugar', 'butter'], 'Caramel Apples': ['apples', 'wooden craft sticks', 'cooking spray', 'package individually wrapped caramels', 'unwrapped', 'milk'], 'German Apple Cake': ['vegetable oil', 'eggs', 'white sugar', 'vanilla extract', 'all-purpose flour', 'ground cinnamon', 'baking soda', 'salt', 'apples -', 'and'], 'Awesome Sausage, Apple and Cranberry Stuffing': ['white bread', 'whole wheat bread', 'ground turkey sausage', 'onion', 'celery', 'dried sage', 'dried rosemary', 'dried thyme', 'golden delicious apple', 'and', 'dried cranberries', 'fresh parsley', 'cooked turkey liver',  ...
#       Unnamed: 0                        recipe_name prep_time cook_time  \
# 0              0           Apple-Cranberry Crostada       NaN       NaN
# 1              1          Apple Pie by Grandma Ople   30 mins     1 hrs
# 2              2        Sarah's Homemade Applesauce   10 mins   15 mins
# 3              3                        Apple Crisp   30 mins   45 mins
# 4              4                  Apple Pie Filling   20 mins   20 mins
# ...          ...                                ...       ...       ...
# 1085        1085                     Date-Nut Balls   15 mins   10 mins
# 1086        1086                       Jamaica Cake       NaN       NaN
# 1087        1087                     Best Hot Sauce   10 mins   20 mins
# 1088        1088               Moist Date Nut Bread   15 mins   50 mins
# 1089        1089  Chef John's Chocolate Energy Bars   15 mins       NaN
#
#          total_time  servings              yield  \
# 0               NaN         8  6 to 8 - servings
# 1     1 hrs 30 mins         8       1 9-inch pie
# 2           25 mins         4                NaN
# 3     1 hrs 15 mins        12    1 9x13-inch pan
# 4     2 hrs 40 mins        40      5 9-inch pies
# ...             ...       ...                ...
# 1085        30 mins        48      4 dozen balls
# 1086            NaN        14  1 - 13x9 inch pan
# 1087        30 mins       100             2 cups
# 1088  1 hrs 35 mins        12    1 9x5-inch loaf
# 1089          3 hrs        12            12 bars
#
#                                             ingredients  \
# 0     3 tablespoons butter, 2 pounds Granny Smith ap...
# 1     8 small Granny Smith apples, or as needed, ½ c...
# 2     4  apples - peeled, cored and chopped, ¾ cup w...
# 3     10 cups all-purpose apples, peeled, cored and ...
# 4     18 cups thinly sliced apples, 3 tablespoons le...
# ...                                                 ...
# 1085  14 tablespoons butter, 1 cup pitted chopped da...
# 1086  2 cups white sugar, 1 ½ cups vegetable oil, 1 ...
# 1087  10  fresh hot chile peppers, stems removed, 1 ...
# 1088  2 ½ cups chopped dates, ¼ cup butter, 1 cup bo...
# 1089  2 cups pitted Medjool dates, roughly chopped, ...
#
#                                              directions  rating  \
# 0     Heat butter in a large skillet over medium-hig...     4.4
# 1     Peel and core apples, then thinly slice. Set a...     4.8
# 2     Combine apples, water, sugar, and cinnamon in ...     4.8
# 3     Preheat the oven to 350 degrees F (175 degrees...     4.7
# 4     Toss apples with lemon juice in a large bowl a...     4.7
# ...                                                 ...     ...
# 1085  Melt butter in a saucepan over medium heat; co...     3.8
# 1086  Mix together sugar, vegetable oil, pecans, flo...     4.6
# 1087  Place peppers, onion, dates, basil, parsley, t...     4.9
# 1088  Preheat the oven to 350 degrees F (175 degrees...     4.5
# 1089  Place cashews, almonds, coconut, dates, cocoa,...     4.8
#
#                                                     url  \
# 0     https://www.allrecipes.com/recipe/76931/apple-...
# 1     https://www.allrecipes.com/recipe/12682/apple-...
# 2     https://www.allrecipes.com/recipe/51301/sarahs...
# 3     https://www.allrecipes.com/recipe/12409/apple-...
# 4     https://www.allrecipes.com/recipe/12681/apple-...
# ...                                                 ...
# 1085  https://www.allrecipes.com/recipe/240653/date-...
# 1086  https://www.allrecipes.com/recipe/7509/jamaica...
# 1087  https://www.allrecipes.com/recipe/242153/best-...
# 1088  https://www.allrecipes.com/recipe/51446/moist-...
# 1089  https://www.allrecipes.com/recipe/254452/chef-...
#
#                                            cuisine_path  \
# 0       /Desserts/Fruit Desserts/Apple Dessert Recipes/
# 1                     /Desserts/Pies/Apple Pie Recipes/
# 2                        /Side Dish/Applesauce Recipes/
# 3     /Desserts/Crisps and Crumbles Recipes/Apple Cr...
# 4                     /Desserts/Pies/Apple Pie Recipes/
# ...                                                 ...
# 1085       /Desserts/Cookies/Fruit Cookie Recipes/Date/
# 1086   /Desserts/Fruit Desserts/Banana Dessert Recipes/
# 1087                  /Side Dish/Sauces and Condiments/
# 1088     /Breakfast and Brunch/Breakfast Bread Recipes/
# 1089  /Appetizers and Snacks/Snacks/Granola Bar Reci...
#
#                                               nutrition  \
# 0     Total Fat 18g 23%, Saturated Fat 7g 34%, Chole...
# 1     Total Fat 19g 24%, Saturated Fat 9g 46%, Chole...
# 2     Total Fat 0g 0%, Sodium 3mg 0%, Total Carbohyd...
# 3     Total Fat 8g 11%, Saturated Fat 5g 25%, Choles...
# 4     Total Fat 0g 0%, Sodium 61mg 3%, Total Carbohy...
# ...                                                 ...
# 1085  Total Fat 5g 6%, Saturated Fat 2g 12%, Cholest...
# 1086  Total Fat 33g 43%, Saturated Fat 4g 21%, Chole...
# 1087  Total Fat 1g 1%, Saturated Fat 0g 1%, Sodium 2...
# 1088  Total Fat 10g 13%, Saturated Fat 3g 16%, Chole...
# 1089  Total Fat 22g 28%, Saturated Fat 7g 36%, Sodiu...
#
#                                                  timing  \
# 0                 Servings: 8, Yield: 6 to 8 - servings
# 1     Prep Time: 30 mins, Cook Time: 1 hrs, Total Ti...
# 2     Prep Time: 10 mins, Cook Time: 15 mins, Total ...
# 3     Prep Time: 30 mins, Cook Time: 45 mins, Total ...
# 4     Prep Time: 20 mins, Cook Time: 20 mins, Additi...
# ...                                                 ...
# 1085  Prep Time: 15 mins, Cook Time: 10 mins, Additi...
# 1086             Servings: 14, Yield: 1 - 13x9 inch pan
# 1087  Prep Time: 10 mins, Cook Time: 20 mins, Total ...
# 1088  Prep Time: 15 mins, Cook Time: 50 mins, Additi...
# 1089  Prep Time: 15 mins, Additional Time: 2 hrs 45 ...
#
#                                                 img_src  \
# 0     https://www.allrecipes.com/thmb/Tf1wH73bfH6Oql...
# 1     https://www.allrecipes.com/thmb/1I95oiTGz6aEpu...
# 2     https://www.allrecipes.com/thmb/VY5d0tZHB8xz6y...
# 3     https://www.allrecipes.com/thmb/uAzhPOh86PfR-N...
# 4     https://www.allrecipes.com/thmb/c0bbYaS1V_mTt_...
# ...                                                 ...
# 1085  https://www.allrecipes.com/thmb/LXm_15zLymhZ7c...
# 1086  https://www.allrecipes.com/thmb/tI7g5xY5-qPV5v...
# 1087  https://www.allrecipes.com/thmb/80wUYzFvbycfxx...
# 1088  https://www.allrecipes.com/thmb/bYsnompJZ6UAF9...
# 1089  https://www.allrecipes.com/thmb/IOoj42MMo8YNKW...
#
#                                     cleaned_ingredients  \
# 0     ['butter', 'granny smith apples or other firm'...
# 1     ['small granny smith apples', 'unsalted butter...
# 2     ['apples -', 'and', 'water', 'white sugar', 'g...
# 3     ['all-purpose apples', 'and', 'white sugar', '...
# 4     ['thinly apples', 'lemon juice', 'water', 'whi...
# ...                                                 ...
# 1085  ['butter', 'dates', 'white sugar', 'crispy ric...
# 1086  ['white sugar', 'vegetable oil', 'pecans', 'al...
# 1087  ['fresh hot chile peppers', 'stems removed', '...
# 1088  ['dates', 'butter', 'boiling water', 'packed b...
# 1089  ['medjool dates', 'roughly', 'raw cashews', 'r...
#
#                                         ingredient_list Dietary Label
# 0     [butter, granny smith apples or other firm, cr...    vegetarian
# 1     [small granny smith apples, unsalted butter, a...    vegetarian
# 2     [apples -, and, water, white sugar, ground cin...         vegan
# 3     [all-purpose apples, and, white sugar, all-pur...    vegetarian
# 4     [thinly apples, lemon juice, water, white suga...         vegan
# ...                                                 ...           ...
# 1085  [butter, dates, white sugar, crispy rice cerea...    vegetarian
# 1086  [white sugar, vegetable oil, pecans, all-purpo...    vegetarian
# 1087  [fresh hot chile peppers, stems removed, onion...          None
# 1088  [dates, butter, boiling water, packed brown su...    vegetarian
# 1089  [medjool dates, roughly, raw cashews, raw or r...         vegan
#
# [1090 rows x 18 columns]

# %%
# Check how many of each label
print(recipe_data["Dietary Label"].value_counts())
# Out:
# Dietary Label
# vegetarian    649
# vegan         310
# Name: count, dtype: int64

# %%
# function to convert time strings to integer minutes
import re

def convert_to_minutes(time_string):
    if pd.isna(time_string):  # Safely handle NaN values
        return None

    # Make sure it's a string
    time_string = str(time_string).lower()

    # Extract days, hours, minutes
    days = re.search(r'(\d+)\s*day', time_string)
    hours = re.search(r'(\d+)\s*hr', time_string)
    minutes = re.search(r'(\d+)\s*min', time_string)

    total_minutes = 0
    if days:
        total_minutes += int(days.group(1)) * 24 * 60
    if hours:
        total_minutes += int(hours.group(1)) * 60
    if minutes:
        total_minutes += int(minutes.group(1))

    return total_minutes

# %%
# clean prep/cook/total time from time string to integer minutes (new column)
recipe_data['cleaned_prep_time'] = recipe_data['prep_time'].apply(convert_to_minutes)
recipe_data['cleaned_cook_time'] = recipe_data['cook_time'].apply(convert_to_minutes)
recipe_data['cleaned_total_time'] = recipe_data['total_time'].apply(convert_to_minutes)

# %%
# check if lobster is OK
recipe_data[recipe_data['recipe_name'] == 'Air Fryer Lobster Tails with Lemon-Garlic Butter']['Dietary Label']
# Out:
# 309    None
# Name: Dietary Label, dtype: object

# %%
# save as csv for use in app.py
recipe_data.to_csv("recipe_data.csv", index=False)
